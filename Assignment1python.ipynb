# %% [markdown]
# Q1: Explain with an example each when to use a for loop and a while loop.
# ans:In for loop condition is not checked it extract from the list or tuple etc wherelse in whileloop it checks the condition
# for example:for loop
# l=[1,2,3,4,5]
# for i in :
# print(i)
# while loop:
# m=5
# n=0
# while n<m:
# print(n)
# n=n+1
# Q2. Write a python program to print the sum and product of the first 10 natural numbers using for
# and while loop.
# ANS:SUM WITH THE HELP OF FOR LOOP:
# sum=0
# for i in range(0,11,1):
#     sum=sum+i
# print(sum)
# SUM WITH THE HELP OF WHILE LOOP
# sum=0
# i=0
# while i<=10:
#       sum=sum+1
#       i=i+1
# print(sum)
# PRODUCT WITH THE HELP OF FOR LOOP:
# product=1
# for i in range(1,11,1):
#     product=product*i
# print(product)
# PRODUCT WITH THE HELP OF WHILE LOOP:
# product=1
# n=1
# while n<11:
#     product=product*n
#     n=n+1
# print(product)
# 3628800
#
# Q3.create a python program to compute the electricity bill for household
# The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per
# unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
# be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.
# You are required to take the units of electricity consumed in a month from the user as input.
# Your program must pass this test case: when the unit of electricity consumed by the user in a month is
# 310, the total electricity bill should be 2250.
# ANS:
# unit=int(input("enter unit"))
# bill=0
# if unit>0 and unit<=100:
#     bill=bill+(unit*4.5)
# elif unit>100 and unit<=200:
#     bill=bill+(100*4.5)+((unit-100)*6)
# elif unit>200 and unit<=300:
#     bill=bill+(100*4.5)+(100*6)+((unit-200)*10)
# else:
#     bill=bill+(100*4.5)+(100*6)+(100*10)+((unit-300)*20)
# bill
#
#
# Q4. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
# number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
# that list.
# ANS:l1=[]
# for i in range(0,101,1):
#     l1.append(i**3)
# l3=[]
# n=100
# i=1
# while i<=n:
#     l3.append(i**3)
#     i=i+1
# l4=[]
# for i in range(0,100,1):
#     if l3[i]%4==0 or l3[i]%5==0:
#         l4.append(l3[i])
#
# Q5. Write a program to filter count vowels in the below-given string.
# string = "I want to become a data scientist"
# ANS:
# count=0
# for i in range(0,len(word),1):
#     if word[i]=="a" or word[i]=="e" or word[i]=="i" or word[i]=="o" or word[i]=="u":
#         count=count+1
# count
# output:12
